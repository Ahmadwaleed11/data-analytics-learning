# %%
import pandas as pd

# %%
df= pd.read_csv('../data/dataset.csv')

# %%
df
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 1          2  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 2          3  CA-2017-138688  12/06/2017  16/06/2017    Second Class
# 3          4  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# 4          5  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# ...      ...             ...         ...         ...             ...
# 9795    9796  CA-2017-125920  21/05/2017  28/05/2017  Standard Class
# 9796    9797  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9797    9798  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9798    9799  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9799    9800  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
df.Sales.describe()
# Out:
# count     9800.000000
# mean       230.769059
# std        626.651875
# min          0.444000
# 25%         17.248000
# 50%         54.490000
# 75%        210.605000
# max      22638.480000
# Name: Sales, dtype: float64

# %%
df.City.describe()
# Out:
# count              9800
# unique              529
# top       New York City
# freq                891
# Name: City, dtype: object

# %%
df.Sales.mean()
# Out:
# np.float64(230.76905945918367)

# %%
df.Product Name.unique()
# Out:
#   Cell In[21], line 1
#     df.Product Name.unique()
#                ^
# SyntaxError: invalid syntax

# %%
df['Product Name'].unique()
# Out:
# <ArrowStringArray>
# [                               'Bush Somerset Collection Bookcase',
#       'Hon Deluxe Fabric Upholstered Stacking Chairs, Rounded Back',
#         'Self-Adhesive Address Labels for Typewriters by Universal',
#                     'Bretford CR4500 Series Slim Rectangular Table',
#                                    'Eldon Fold 'N Roll Cart System',
#  'Eldon Expressions Wood and Plastic Desk Accessories, Cherry Wood',
#                                                        'Newell 322',
#                                    'Mitel 5320 IP Phone VoIP phone',
#              'DXL Angle-View Binders with Locking Rings by Samsill',
#                                  'Belkin F5C206VTEL 6 Outlet Surge',
#  ...
#      'Global Enterprise Series Seating Low-Back Swivel/Tilt Chairs',
#   'Self-Adhesive Address Labels for Typewriters with Dispenser Box',
#              'Office Star - Task Chair with Contemporary Loop Arms',
# ...

# %%
df.columns.tolist()
# Out:
# ['Row ID',
#  'Order ID',
#  'Order Date',
#  'Ship Date',
#  'Ship Mode',
#  'Customer ID',
#  'Customer Name',
#  'Segment',
#  'Country',
#  'City',
#  'State',
#  'Postal Code',
#  'Region',
#  'Product ID',
#  'Category',
#  'Sub-Category',
#  'Product Name',
#  'Sales']

# %%
df.City.value_counts()
# Out:
# City
# New York City        891
# Los Angeles          728
# Philadelphia         532
# San Francisco        500
# Seattle              426
#                     ...
# Hagerstown             1
# East Orange            1
# Arlington Heights      1
# San Luis Obispo        1
# Springdale             1
# Name: count, Length: 529, dtype: int64

# %%
df
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 1          2  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 2          3  CA-2017-138688  12/06/2017  16/06/2017    Second Class
# 3          4  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# 4          5  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# ...      ...             ...         ...         ...             ...
# 9795    9796  CA-2017-125920  21/05/2017  28/05/2017  Standard Class
# 9796    9797  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9797    9798  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9798    9799  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9799    9800  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
df.groupby('City').Sales.min
# Out:
# <bound method GroupBy.min of <pandas.api.typing.SeriesGroupBy object at 0x00000152C32A2FD0>>

# %%
df.groupby('Sales').City
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 df.groupby('Sales').City()
#
# TypeError: 'SeriesGroupBy' object is not callable

# %%
df
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 1          2  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 2          3  CA-2017-138688  12/06/2017  16/06/2017    Second Class
# 3          4  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# 4          5  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# ...      ...             ...         ...         ...             ...
# 9795    9796  CA-2017-125920  21/05/2017  28/05/2017  Standard Class
# 9796    9797  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9797    9798  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9798    9799  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9799    9800  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
df.groupby('Category').Sales.sum()
# Out:
# Category
# Furniture          728658.5757
# Office Supplies    705422.3340
# Technology         827455.8730
# Name: Sales, dtype: float64

# %%
df.groupby(['Category','Sub-Category']).Sales.sum()
# Out:
# Category         Sub-Category
# Furniture        Bookcases       113813.1987
#                  Chairs          322822.7310
#                  Furnishings      89212.0180
#                  Tables          202810.6280
# Office Supplies  Appliances      104618.4030
#                  Art              26705.4100
#                  Binders         200028.7850
#                  Envelopes        16128.0460
#                  Fasteners         3001.9600
#                  Labels           12347.7260
#                  Paper            76828.3040
#                  Storage         219343.3920
#                  Supplies         46420.3080
# Technology       Accessories     164186.7000
#                  Copiers         146248.0940
#                  Machines        189238.6310
#                  Phones          327782.4480
# Name: Sales, dtype: float64

# %%
df.groupby(['Category','Sub-Category']).Sales.min()
# Out:
# Category         Sub-Category
# Furniture        Bookcases        35.490
#                  Chairs           26.640
#                  Furnishings       1.892
#                  Tables           24.368
# Office Supplies  Appliances        0.444
#                  Art               1.344
#                  Binders           0.556
#                  Envelopes         1.632
#                  Fasteners         1.240
#                  Labels            2.088
#                  Paper             3.380
#                  Storage           4.464
#                  Supplies          1.744
# Technology       Accessories       0.990
#                  Copiers         299.990
#                  Machines         11.560
#                  Phones            2.970
# Name: Sales, dtype: float64

# %%
df.groupby(['Category','Sub-Category']).Sales.count()
# Out:
# Category         Sub-Category
# Furniture        Bookcases        226
#                  Chairs           607
#                  Furnishings      931
#                  Tables           314
# Office Supplies  Appliances       459
#                  Art              785
#                  Binders         1492
#                  Envelopes        248
#                  Fasteners        214
#                  Labels           357
#                  Paper           1338
#                  Storage          832
#                  Supplies         184
# Technology       Accessories      756
#                  Copiers           66
#                  Machines         115
#                  Phones           876
# Name: Sales, dtype: int64

# %%
df.groupby(['Category','Sub-Category']).Sales.agg(['sum','count','mean'])
# Out:
#                                       sum  count         mean
# Category        Sub-Category
# Furniture       Bookcases     113813.1987    226   503.598224
#                 Chairs        322822.7310    607   531.833165
#                 Furnishings    89212.0180    931    95.823865
#                 Tables        202810.6280    314   645.893720
# Office Supplies Appliances    104618.4030    459   227.926804
#                 Art            26705.4100    785    34.019631
#                 Binders       200028.7850   1492   134.067550
#                 Envelopes      16128.0460    248    65.032444
#                 Fasteners       3001.9600    214    14.027850
#                 Labels         12347.7260    357    34.587468
#                 Paper          76828.3040   1338    57.420257
#                 Storage       219343.3920    832   263.633885
#                 Supplies       46420.3080    184   252.284283
# Technology      Accessories   164186.7000    756   217.178175
# ...

# %%
df.pivot_table(values='Sales', index='Region', columns='Category')
# Out:
# Category   Furniture  Office Supplies  Technology
# Region
# Central   341.100983       116.933698  413.576490
# East      349.342450       119.940499  499.272347
# South     357.458528       126.576573  512.786187
# West      355.062584       116.917478  420.042326
