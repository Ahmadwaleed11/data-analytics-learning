# %%
people={
    'first_name':['ahmad','harry','ali'],
    'last_name':['waleed','harry','harry'],
    'email':['ahmad@mail.com','harry@mail.com','ali@mail.com']
}

# %%
import pandas as pd

# %%
df=pd.DataFrame(people)

# %%
df
# Out:
#   first_name last_name           email
# 0      ahmad    waleed  ahmad@mail.com
# 1      harry     harry  harry@mail.com
# 2        ali     harry    ali@mail.com

# %%
df['last_name']=='harry'
# Out:
# 0    False
# 1     True
# 2     True
# Name: last_name, dtype: bool

# %%
filter=(df['last_name']=='harry') & (df['first_name']=='ali')

# %%
df[filter]
# Out:
#   first_name last_name         email
# 2        ali     harry  ali@mail.com

# %%
df.loc[filter,'email']
# Out:
# 2    ali@mail.com
# Name: email, dtype: str

# %%
df
# Out:
#   first_name last_name           email
# 0      ahmad    waleed  ahmad@mail.com
# 1      harry     harry  harry@mail.com
# 2        ali     harry    ali@mail.com

# %%
df.columns=[x.upper() for x in df.columns]

# %%
df
# Out:
#   FIRST_NAME LAST_NAME           EMAIL
# 0      ahmad    waleed  ahmad@mail.com
# 1      harry     harry  harry@mail.com
# 2        ali     harry    ali@mail.com

# %%
df.columns=df.columns.str.replace('_',' ')

# %%
df
# Out:
#   FIRST NAME LAST NAME           EMAIL
# 0      ahmad    waleed  ahmad@mail.com
# 1      harry     harry  harry@mail.com
# 2        ali     harry    ali@mail.com

# %%
df
# Out:
#   FIRST NAME LAST NAME           EMAIL
# 0      ahmad    waleed  ahmad@mail.com
# 1      harry     harry  harry@mail.com
# 2        ali     harry    ali@mail.com

# %%
df['LAST NAME']
# Out:
# 0    waleed
# 1     harry
# 2     harry
# Name: LAST NAME, dtype: str

# %%
df.columns=df.columns.str.replace('_E_M_A_I_L_','email')

# %%
df
# Out:
#   first_name last_name           email
# 0      ahmad    waleed  ahmad@mail.com
# 1      harry     harry  harry@mail.com
# 2        ali     harry    ali@mail.com

# %%
df
# Out:
#   first_name last_name           email
# 0      ahmad    waleed  ahmad@mail.com
# 1      harry     harry  harry@mail.com
# 2        ali     harry    ali@mail.com

# %%
df.columns=[x.upper() for x in df.columns]

# %%
df
# Out:
#   FIRST_NAME LAST_NAME           EMAIL
# 0      ahmad    waleed  ahmad@mail.com
# 1      harry     harry  harry@mail.com
# 2        ali     harry    ali@mail.com

# %%
df.columns=[x.lower() for x in df.columns]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 df.columns=[x.lower() for x in df.columns]
#
# AttributeError: 'builtin_function_or_method' object has no attribute 'lower'

# %%
df
# Out:
#   <built-in method lower of str object at 0x000001F3ED820730>  \
# 0                                              ahmad
# 1                                              harry
# 2                                                ali
#
#   <built-in method lower of str object at 0x000001F3ED8202F0>  \
# 0                                             waleed
# 1                                              harry
# 2                                              harry
#
#   <built-in method lower of str object at 0x000001F3ED2BBFC0>
# 0                                     ahmad@mail.com
# 1                                     harry@mail.com
# 2                                       ali@mail.com

# %%
df
# Out:
#   <built-in method lower of str object at 0x000001F3ED820730>  \
# 0                                              ahmad
# 1                                              harry
# 2                                                ali
#
#   <built-in method lower of str object at 0x000001F3ED8202F0>  \
# 0                                             waleed
# 1                                              harry
# 2                                              harry
#
#   <built-in method lower of str object at 0x000001F3ED2BBFC0>
# 0                                     ahmad@mail.com
# 1                                     harry@mail.com
# 2                                       ali@mail.com

# %%
df.columns=['first_name','last_name','email']

# %%
dfd
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 dfd
#
# NameError: name 'dfd' is not defined

# %%
df
# Out:
#   first_name last_name           email
# 0      ahmad    waleed  ahmad@mail.com
# 1      harry     harry  harry@mail.com
# 2        ali     harry    ali@mail.com

# %%
df.columns=[x.upper() for x in df.columns]

# %%
df
# Out:
#   FIRST_NAME LAST_NAME           EMAIL
# 0      ahmad    waleed  ahmad@mail.com
# 1      harry     harry  harry@mail.com
# 2        ali     harry    ali@mail.com

# %%
df.columns=[x.lower() for x in df.columns]

# %%
df
# Out:
#   first_name last_name           email
# 0      ahmad    waleed  ahmad@mail.com
# 1      harry     harry  harry@mail.com
# 2        ali     harry    ali@mail.com

# %%
df.rename(columns={'first_name':'first','last_name':'last'} , inplace=True)

# %%
df
# Out:
#    first    last           email
# 0  ahmad  waleed  ahmad@mail.com
# 1  harry   harry  harry@mail.com
# 2    ali   harry    ali@mail.com
