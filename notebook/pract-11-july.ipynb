# %%
people={
    'first':['ahmad','zaid','majid'],
    'last':['waleed','ali','gohar'],
    'email':['ahmad@mail.com','zaid@mail.com','majid@mail.com']
}

# %%
import pandas as pd

# %%
df=pd.DataFrame(people)

# %%
df
# Out:
#    first    last           email
# 0  ahmad  waleed  ahmad@mail.com
# 1   zaid     ali   zaid@mail.com
# 2  majid   gohar  majid@mail.com

# %%
peeps={
    'first':['tony','steve'],
    'last':['stark','roger'],
    'email':['tony@mail.com','steve@mail.com']
}

# %%
avenger=pd.DataFrame(peeps)

# %%
avenger
# Out:
#    first   last           email
# 0   tony  stark   tony@mail.com
# 1  steve  roger  steve@mail.com

# %%
df=pd.concat([df,pd.DataFrame([{'first':'Tom','last':'Holand'}])],ignore_index=True)

# %%
df
# Out:
#    first    last           email
# 0  ahmad  waleed  ahmad@mail.com
# 1   zaid     ali   zaid@mail.com
# 2  majid   gohar  majid@mail.com
# 3    Tom  Holand             NaN

# %%
df
# Out:
#    first    last           email
# 0  ahmad  waleed  ahmad@mail.com
# 1   zaid     ali   zaid@mail.com
# 2  majid   gohar  majid@mail.com
# 3    Tom  Holand             NaN

# %%
avenger
# Out:
#    first   last           email
# 0   tony  stark   tony@mail.com
# 1  steve  roger  steve@mail.com

# %%
df is avenger
# Out:
# False

# %%
print("DF:")
print(df)

print("\nAVENGER:")
print(avenger)

print("\nDF shape:", df.shape)
print("AVENGER shape:", avenger.shape)
# Out:
# DF:
#    first    last           email
# 0  ahmad  waleed  ahmad@mail.com
# 1   zaid     ali   zaid@mail.com
# 2  majid   gohar  majid@mail.com
# 3    Tom  Holand             NaN
#
# AVENGER:
#    first   last           email
# 0   tony  stark   tony@mail.com
# 1  steve  roger  steve@mail.com
#
# DF shape: (4, 3)
# AVENGER shape: (2, 3)

# %%
print(df)
print(avenger)
print(df.shape)
print(avenger.shape)
# Out:
#    first    last           email
# 0  ahmad  waleed  ahmad@mail.com
# 1   zaid     ali   zaid@mail.com
# 2  majid   gohar  majid@mail.com
# 3    Tom  Holand             NaN
#    first   last           email
# 0   tony  stark   tony@mail.com
# 1  steve  roger  steve@mail.com
# (4, 3)
# (2, 3)

# %%
df
# Out:
#    first    last           email
# 0  ahmad  waleed  ahmad@mail.com
# 1   zaid     ali   zaid@mail.com
# 2  majid   gohar  majid@mail.com
# 3    Tom  Holand             NaN

# %%
avenger
# Out:
#    first   last           email
# 0   tony  stark   tony@mail.com
# 1  steve  roger  steve@mail.com

# %%
df=pd.concat([df,pd.DataFrame([{'first':'spider','last':'man'}])],ignore_index=True)

# %%
df
# Out:
#     first    last           email
# 0   ahmad  waleed  ahmad@mail.com
# 1    zaid     ali   zaid@mail.com
# 2   majid   gohar  majid@mail.com
# 3     Tom  Holand             NaN
# 4  spider     man             NaN

# %%
avenger=pd.concat([avenger,pd.DataFrame([{'first':'iron','last':'man'}])], ignore_index=True)

# %%
avenger
# Out:
#    first   last           email
# 0   tony  stark   tony@mail.com
# 1  steve  roger  steve@mail.com
# 2   iron    man             NaN

# %%
df=pd.concat([avenger,df],ignore_index=True)

# %%
df
# Out:
#     first    last           email
# 0    tony   stark   tony@mail.com
# 1   steve   roger  steve@mail.com
# 2    iron     man             NaN
# 3   ahmad  waleed  ahmad@mail.com
# 4    zaid     ali   zaid@mail.com
# 5   majid   gohar  majid@mail.com
# 6     Tom  Holand             NaN
# 7  spider     man             NaN

# %%
filter=df['first']=='spider'
df.drop(index=df[filter].index)
# Out:
#    first    last           email
# 0   tony   stark   tony@mail.com
# 1  steve   roger  steve@mail.com
# 2   iron     man             NaN
# 3  ahmad  waleed  ahmad@mail.com
# 4   zaid     ali   zaid@mail.com
# 5  majid   gohar  majid@mail.com
# 6    Tom  Holand             NaN

# %%
df
# Out:
#     first    last           email
# 0    tony   stark   tony@mail.com
# 1   steve   roger  steve@mail.com
# 2    iron     man             NaN
# 3   ahmad  waleed  ahmad@mail.com
# 4    zaid     ali   zaid@mail.com
# 5   majid   gohar  majid@mail.com
# 6     Tom  Holand             NaN
# 7  spider     man             NaN

# %%
df.sort_values(by='last', ascending=False)
# Out:
#     first    last           email
# 3   ahmad  waleed  ahmad@mail.com
# 0    tony   stark   tony@mail.com
# 1   steve   roger  steve@mail.com
# 2    iron     man             NaN
# 7  spider     man             NaN
# 5   majid   gohar  majid@mail.com
# 4    zaid     ali   zaid@mail.com
# 6     Tom  Holand             NaN

# %%
df.sort_values(by=['last','first'], ascending=False)
# Out:
#     first    last           email
# 3   ahmad  waleed  ahmad@mail.com
# 0    tony   stark   tony@mail.com
# 1   steve   roger  steve@mail.com
# 7  spider     man             NaN
# 2    iron     man             NaN
# 5   majid   gohar  majid@mail.com
# 4    zaid     ali   zaid@mail.com
# 6     Tom  Holand             NaN

# %%
sales=pd.read_csv('../data/dataset.csv')

# %%
sales
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 1          2  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 2          3  CA-2017-138688  12/06/2017  16/06/2017    Second Class
# 3          4  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# 4          5  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# ...      ...             ...         ...         ...             ...
# 9795    9796  CA-2017-125920  21/05/2017  28/05/2017  Standard Class
# 9796    9797  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9797    9798  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9798    9799  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9799    9800  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
sales.set_index('Row ID',inplace=True)

# %%
sales
# Out:
#               Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# Row ID
# 1       CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 2       CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 3       CA-2017-138688  12/06/2017  16/06/2017    Second Class    DV-13045
# 4       US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 5       US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# ...                ...         ...         ...             ...         ...
# 9796    CA-2017-125920  21/05/2017  28/05/2017  Standard Class    SH-19975
# 9797    CA-2016-128608  12/01/2016  17/01/2016  Standard Class    CS-12490
# 9798    CA-2016-128608  12/01/2016  17/01/2016  Standard Class    CS-12490
# 9799    CA-2016-128608  12/01/2016  17/01/2016  Standard Class    CS-12490
# 9800    CA-2016-128608  12/01/2016  17/01/2016  Standard Class    CS-12490
#
# ...

# %%
sales.sort_value(by='Country')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 sales.sort_value(by='Country')
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\generic.py:6206, in NDFrame.__getattr__(self, name)
#    6202             and name not in self._accessors
#    6203             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6204         ):
#    6205             return self[name]
# -> 6206         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'sort_value'

# %%
sales.sort_values(by='Country', inplace=True)

# %%
sales
# Out:
#               Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# Row ID
# 1       CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 2       CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 3       CA-2017-138688  12/06/2017  16/06/2017    Second Class    DV-13045
# 4       US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 5       US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# ...                ...         ...         ...             ...         ...
# 9796    CA-2017-125920  21/05/2017  28/05/2017  Standard Class    SH-19975
# 9797    CA-2016-128608  12/01/2016  17/01/2016  Standard Class    CS-12490
# 9798    CA-2016-128608  12/01/2016  17/01/2016  Standard Class    CS-12490
# 9799    CA-2016-128608  12/01/2016  17/01/2016  Standard Class    CS-12490
# 9800    CA-2016-128608  12/01/2016  17/01/2016  Standard Class    CS-12490
#
# ...

# %%
sales.head(60)
# Out:
#               Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# Row ID
# 1       CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 2       CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 3       CA-2017-138688  12/06/2017  16/06/2017    Second Class    DV-13045
# 4       US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 5       US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 6       CA-2015-115812  09/06/2015  14/06/2015  Standard Class    BH-11710
# 7       CA-2015-115812  09/06/2015  14/06/2015  Standard Class    BH-11710
# 8       CA-2015-115812  09/06/2015  14/06/2015  Standard Class    BH-11710
# 9       CA-2015-115812  09/06/2015  14/06/2015  Standard Class    BH-11710
# 10      CA-2015-115812  09/06/2015  14/06/2015  Standard Class    BH-11710
# 11      CA-2015-115812  09/06/2015  14/06/2015  Standard Class    BH-11710
# ...

# %%
sales['Country'].head(40)
# Out:
# Row ID
# 1     United States
# 2     United States
# 3     United States
# 4     United States
# 5     United States
# 6     United States
# 7     United States
# 8     United States
# 9     United States
# 10    United States
# 11    United States
# 12    United States
# 13    United States
# 14    United States
# 15    United States
# 16    United States
# 17    United States
# 18    United States
# 19    United States
# 20    United States
# 21    United States
# 22    United States
# 23    United States
# 24    United States
# 25    United States
# 26    United States
# 27    United States
# 28    United States
# 29    United States
# 30    United States
# 31    United States
# 32    United States
# 33    United States
# 34    United States
# 35    United States
# 36    United States
# 37    United States
# 38    United States
# 39    United States
# 40    United States
# Name: Country, dtype: str

# %%
sales[['Country','Sales']].head(40)
# Out:
#               Country      Sales
# Row ID
# 1       United States   261.9600
# 2       United States   731.9400
# 3       United States    14.6200
# 4       United States   957.5775
# 5       United States    22.3680
# 6       United States    48.8600
# 7       United States     7.2800
# 8       United States   907.1520
# 9       United States    18.5040
# 10      United States   114.9000
# 11      United States  1706.1840
# 12      United States   911.4240
# 13      United States    15.5520
# 14      United States   407.9760
# 15      United States    68.8100
# 16      United States     2.5440
# 17      United States   665.8800
# 18      United States    55.5000
# 19      United States     8.5600
# 20      United States   213.4800
# 21      United States    22.7200
# 22      United States    19.4600
# 23      United States    60.3400
# 24      United States    71.3720
# 25      United States  1044.6300
# 26      United States    11.6480
# 27      United States    90.5700
# ...

# %%
sales.sort_values(by=['Country','Sales'], ascending=[True,False], inplace=True)

# %%
sales
# Out:
#               Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# Row ID
# 2698    CA-2015-145317  18/03/2015  23/03/2015  Standard Class    SM-20320
# 6827    CA-2017-118689  02/10/2017  09/10/2017  Standard Class    TC-20980
# 8154    CA-2018-140151  23/03/2018  25/03/2018     First Class    RB-19360
# 2624    CA-2018-127180  22/10/2018  24/10/2018     First Class    TA-21385
# 4191    CA-2018-166709  17/11/2018  22/11/2018  Standard Class    HL-15040
# ...                ...         ...         ...             ...         ...
# 2107    US-2015-152723  26/09/2015  26/09/2015        Same Day    HG-14965
# 4712    CA-2015-112403  31/03/2015  31/03/2015        Same Day    JO-15280
# 8659    CA-2017-168361  21/06/2017  25/06/2017  Standard Class    KB-16600
# 9293    CA-2018-124114  02/03/2018  02/03/2018        Same Day    RS-19765
# 4102    US-2018-102288  19/06/2018  23/06/2018  Standard Class    ZC-21910
#
# ...

# %%
df[['Country','Sales']].head(50)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 df[['Country','Sales']].head(50)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\frame.py:4384, in DataFrame.__getitem__(self, key)
#    4380                 indexer = [indexer]
#    4381         else:
#    4382             if is_iterator(key):
#    4383                 key = list(key)
# -> 4384             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4385
#    4386         # take() does not accept boolean indexers
#    4387         if getattr(indexer, "dtype", None) == bool:
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\indexes\base.py:6302, in Index._get_indexer_strict(self, key, axis_name)
#    6299 else:
#    6300     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# ...

# %%
sales[['Country','Sales']].head(40)
# Out:
#               Country      Sales
# Row ID
# 2698    United States  22638.480
# 6827    United States  17499.950
# 8154    United States  13999.960
# 2624    United States  11199.968
# 4191    United States  10499.970
# 9040    United States   9892.740
# 4099    United States   9449.950
# 4278    United States   9099.930
# 8489    United States   8749.950
# 6426    United States   8399.976
# 2506    United States   8187.650
# 166     United States   8159.952
# 684     United States   7999.980
# 6627    United States   6999.960
# 510     United States   6354.950
# 6521    United States   5443.960
# 7667    United States   5399.910
# 6341    United States   5199.960
# 8859    United States   5083.960
# 5885    United States   4912.590
# 1086    United States   4899.930
# 8991    United States   4899.930
# 4219    United States   4799.984
# 1804    United States   4663.736
# 8205    United States   4643.800
# 2493    United States   4548.810
# 7819    United States   4535.976
# ...
