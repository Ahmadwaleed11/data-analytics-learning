# %%
import pandas as pd

# %%
df=pd.read_csv('../data/dataset.csv')

# %%
df
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 1          2  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 2          3  CA-2017-138688  12/06/2017  16/06/2017    Second Class
# 3          4  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# 4          5  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# ...      ...             ...         ...         ...             ...
# 9795    9796  CA-2017-125920  21/05/2017  28/05/2017  Standard Class
# 9796    9797  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9797    9798  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9798    9799  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9799    9800  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
df.set_index('Row ID', inplace=True)

# %%
df
# Out:
#               Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# Row ID
# 1       CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 2       CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 3       CA-2017-138688  12/06/2017  16/06/2017    Second Class    DV-13045
# 4       US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 5       US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# ...                ...         ...         ...             ...         ...
# 9796    CA-2017-125920  21/05/2017  28/05/2017  Standard Class    SH-19975
# 9797    CA-2016-128608  12/01/2016  17/01/2016  Standard Class    CS-12490
# 9798    CA-2016-128608  12/01/2016  17/01/2016  Standard Class    CS-12490
# 9799    CA-2016-128608  12/01/2016  17/01/2016  Standard Class    CS-12490
# 9800    CA-2016-128608  12/01/2016  17/01/2016  Standard Class    CS-12490
#
# ...

# %%
df.describe()
# Out:
#         Postal Code         Sales
# count   9789.000000   9800.000000
# mean   55273.322403    230.769059
# std    32041.223413    626.651875
# min     1040.000000      0.444000
# 25%    23223.000000     17.248000
# 50%    58103.000000     54.490000
# 75%    90008.000000    210.605000
# max    99301.000000  22638.480000

# %%
df['Sales'].median()
# Out:
# np.float64(54.489999999999995)

# %%
country_gap=df.groupby('City')
# country_gap.get_group('United States')

# %%
country_gap[['Sales','Segment','Customer Name','Ship Date']].value_counts().loc['Henderson']
# Out:
# Sales     Segment      Customer Name     Ship Date
# 261.960   Consumer     Claire Gute       11/11/2017    1
# 731.940   Consumer     Claire Gute       11/11/2017    1
# 152.940   Consumer     Darren Koutras    11/12/2016    1
# 283.920   Consumer     Darren Koutras    11/12/2016    1
# 10.670    Consumer     Rob Dowd          03/11/2016    1
# 36.630    Consumer     Rob Dowd          03/11/2016    1
# 24.100    Consumer     Rob Dowd          03/11/2016    1
# 33.110    Consumer     Rob Dowd          03/11/2016    1
# 196.450   Corporate    Adam Hart         18/04/2018    1
# 94.740    Corporate    Karen Carlisle    03/01/2017    1
# 60.640    Corporate    Karen Carlisle    03/01/2017    1
# 76.300    Corporate    Karen Carlisle    03/01/2017    1
# 364.800   Corporate    Karen Carlisle    03/01/2017    1
# 821.880   Consumer     Adrian Barton     23/11/2018    1
# 21.960    Consumer     Adrian Barton     23/11/2018    1
# 61.000    Home Office  Daniel Byrd       02/04/2018    1
# ...

# %%
country_gap['Sales'].agg(['median','mean','sum'])
# Out:
#               median        mean       sum
# City
# Aberdeen      25.500   25.500000    25.500
# Abilene        1.392    1.392000     1.392
# Akron         48.768  136.212200  2724.244
# Albuquerque  104.525  158.582857  2220.160
# Alexandria    27.025  344.973125  5519.570
# ...              ...         ...       ...
# Woonsocket    48.615   48.887500   195.550
# Yonkers       59.520  510.511067  7657.666
# York          65.584  163.595600   817.978
# Yucaipa       50.800   50.800000    50.800
# Yuma         115.192  210.216250   840.865
#
# [529 rows x 3 columns]

# %%
country_gap['Sales'].value_counts().head(50)
# Out:
# City         Sales
# Aberdeen     25.500      1
# Abilene      1.392       1
# Akron        21.744      1
#              284.364     1
#              665.408     1
#              149.232     1
#              15.936      1
#              8.256       1
#              25.560      1
#              4.368       1
#              11.520      1
#              221.024     1
#              14.952      1
#              323.982     1
#              2.286       1
#              14.352      1
#              71.976      1
#              85.056      1
#              17.184      1
#              259.896     1
#              247.188     1
#              279.960     1
# Albuquerque  595.000     1
#              79.872      1
#              90.800      1
#              140.736     1
#              214.950     1
#              45.360      1
#              288.240     1
#              23.976      1
#              33.290      1
#              27.180      1
#              118.250     1
# ...

# %%
country_cat=country_gap['Category'].value_counts()

# %%
country_cat
# Out:
# City      Category
# Aberdeen  Office Supplies     1
# Abilene   Office Supplies     1
# Akron     Office Supplies    13
#           Technology          5
#           Furniture           2
#                              ..
# York      Office Supplies     4
#           Furniture           1
# Yucaipa   Office Supplies     1
# Yuma      Office Supplies     2
#           Technology          2
# Name: count, Length: 1186, dtype: int64

# %%
country_sal=country_gap['Sales'].value_counts()

# %%
country_sal
# Out:
# City      Sales
# Aberdeen  25.500     1
# Abilene   1.392      1
# Akron     21.744     1
#           284.364    1
#           665.408    1
#                     ..
# Yucaipa   50.800     1
# Yuma      44.856     1
#           185.528    1
#           599.985    1
#           10.496     1
# Name: count, Length: 9365, dtype: int64

# %%
salebycategory=pd.concat([country_sal,country_cat],axis='columns',sort=False)

# %%
salebycategory
# Out:
#                           count  count
# City
# Aberdeen 25.5               1.0    NaN
# Abilene  1.392              1.0    NaN
# Akron    21.744             1.0    NaN
#          284.364            1.0    NaN
#          665.408            1.0    NaN
# ...                         ...    ...
# York     Office Supplies    NaN    4.0
#          Furniture          NaN    1.0
# Yucaipa  Office Supplies    NaN    1.0
# Yuma     Office Supplies    NaN    2.0
#          Technology         NaN    2.0
#
# [10551 rows x 2 columns]
