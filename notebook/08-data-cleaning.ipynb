# %%
import pandas as pd
import numpy as np

# %%
people={
    'first':['ahmd','zaid',np.nan,'majid',None,'missing','Na'],
    'last':['waleed','ali',np.nan,'Na',None,'ali','missing'],
    'email':['ahmad@mail.com','zaaid@mail.com',None,'majid@mail.com','ali@mail.com',None,'Na'],
    'age':['23','24','45',None,None,'23','Na']
}

# %%
df=pd.DataFrame(people)

# %%
df
# Out:
#      first     last           email  age
# 0     ahmd   waleed  ahmad@mail.com   23
# 1     zaid      ali  zaaid@mail.com   24
# 2      NaN      NaN             NaN   45
# 3    majid       Na  majid@mail.com  NaN
# 4      NaN      NaN    ali@mail.com  NaN
# 5  missing      ali             NaN   23
# 6       Na  missing              Na   Na

# %%
df.dropna(axis='index', how='all', subset=['age'])
# Out:
#      first     last           email age
# 0     ahmd   waleed  ahmad@mail.com  23
# 1     zaid      ali  zaaid@mail.com  24
# 2      NaN      NaN             NaN  45
# 5  missing      ali             NaN  23
# 6       Na  missing              Na  Na

# %%
df.replace('Na',np.nan,inplace=True)
df.replace('missing', np.nan,inplace=True)
df
# Out:
#    first    last           email  age
# 0   ahmd  waleed  ahmad@mail.com   23
# 1   zaid     ali  zaaid@mail.com   24
# 2    NaN     NaN             NaN   45
# 3  majid     NaN  majid@mail.com  NaN
# 4    NaN     NaN    ali@mail.com  NaN
# 5    NaN     ali             NaN   23
# 6    NaN     NaN             NaN  NaN

# %%
df.dropna(subset=['email'])
# Out:
#    first    last           email  age
# 0   ahmd  waleed  ahmad@mail.com   23
# 1   zaid     ali  zaaid@mail.com   24
# 3  majid     NaN  majid@mail.com  NaN
# 4    NaN     NaN    ali@mail.com  NaN

# %%
df.dtypes
# Out:
# first    str
# last     str
# email    str
# age      str
# dtype: object

# %%
df['age']=df['age'].astype(float)

# %%
df.dtypes
# Out:
# first        str
# last         str
# email        str
# age      float64
# dtype: object

# %%
df['age']=df['age'].astype(str)

# %%
df
# Out:
#    first    last           email   age
# 0   ahmd  waleed  ahmad@mail.com  23.0
# 1   zaid     ali  zaaid@mail.com  24.0
# 2    NaN     NaN             NaN  45.0
# 3  majid     NaN  majid@mail.com   NaN
# 4    NaN     NaN    ali@mail.com   NaN
# 5    NaN     ali             NaN  23.0
# 6    NaN     NaN             NaN   NaN

# %%
df
# Out:
#    first    last           email   age
# 0   ahmd  waleed  ahmad@mail.com  23.0
# 1   zaid     ali  zaaid@mail.com  24.0
# 2    NaN     NaN             NaN  45.0
# 3  majid     NaN  majid@mail.com   NaN
# 4    NaN     NaN    ali@mail.com   NaN
# 5    NaN     ali             NaN  23.0
# 6    NaN     NaN             NaN   NaN

# %%
df.dtypes
# Out:
# first    str
# last     str
# email    str
# age      str
# dtype: object

# %%
df['age'].mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 df['age'].mean()
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\util\_decorators.py:336, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     330 if len(args) > num_allow_args:
#     331     warnings.warn(
#     332         msg.format(arguments=_format_argument_list(allow_args)),
#     333         klass,
#     334         stacklevel=find_stack_level(),
#     335     )
# --> 336 return func(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\series.py:8113, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
#    8063 @deprecate_nonkeyword_arguments(Pandas4Warning, allowed_args=["self"], name="mean")
#    8064 def mean(
#    8065     self,
#    (...)   8069     **kwargs,
# ...

# %%
df['age']=df['age'].astype(float)

# %%
df.dtypes
# Out:
# first        str
# last         str
# email        str
# age      float64
# dtype: object

# %%
df['age'].mean()
# Out:
# np.float64(28.75)

# %%
df2=pd.read_csv('../data/dataset.csv')

# %%
df2
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 1          2  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 2          3  CA-2017-138688  12/06/2017  16/06/2017    Second Class
# 3          4  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# 4          5  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# ...      ...             ...         ...         ...             ...
# 9795    9796  CA-2017-125920  21/05/2017  28/05/2017  Standard Class
# 9796    9797  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9797    9798  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9798    9799  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9799    9800  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
df2['Sales'].unique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 df2['Sales'].unique().head(50)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'head'

# %%
df2.head(50)
# Out:
#     Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0        1  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 1        2  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 2        3  CA-2017-138688  12/06/2017  16/06/2017    Second Class
# 3        4  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# 4        5  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# 5        6  CA-2015-115812  09/06/2015  14/06/2015  Standard Class
# 6        7  CA-2015-115812  09/06/2015  14/06/2015  Standard Class
# 7        8  CA-2015-115812  09/06/2015  14/06/2015  Standard Class
# 8        9  CA-2015-115812  09/06/2015  14/06/2015  Standard Class
# 9       10  CA-2015-115812  09/06/2015  14/06/2015  Standard Class
# 10      11  CA-2015-115812  09/06/2015  14/06/2015  Standard Class
# 11      12  CA-2015-115812  09/06/2015  14/06/2015  Standard Class
# 12      13  CA-2018-114412  15/04/2018  20/04/2018  Standard Class
# ...
