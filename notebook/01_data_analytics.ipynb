# %%
import pandas as pd

# %%
df=pd.read_csv('data/dataset.csv')

# %%
print(df)
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 1          2  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 2          3  CA-2017-138688  12/06/2017  16/06/2017    Second Class
# 3          4  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# 4          5  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# ...      ...             ...         ...         ...             ...
# 9795    9796  CA-2017-125920  21/05/2017  28/05/2017  Standard Class
# 9796    9797  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9797    9798  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9798    9799  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9799    9800  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
print(df.shape)
# Out:
# (9800, 18)

# %%
df.head(10)
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 1       2  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 2       3  CA-2017-138688  12/06/2017  16/06/2017    Second Class    DV-13045
# 3       4  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 4       5  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 5       6  CA-2015-115812  09/06/2015  14/06/2015  Standard Class    BH-11710
# 6       7  CA-2015-115812  09/06/2015  14/06/2015  Standard Class    BH-11710
# 7       8  CA-2015-115812  09/06/2015  14/06/2015  Standard Class    BH-11710
# 8       9  CA-2015-115812  09/06/2015  14/06/2015  Standard Class    BH-11710
# 9      10  CA-2015-115812  09/06/2015  14/06/2015  Standard Class    BH-11710
#
#      Customer Name    Segment        Country             City       State  \
# ...

# %%
df=pd.read_csv('data/dataset.csv',index_col=1)

# %%
print(df)
# Out:
#                 Row ID  Order Date   Ship Date       Ship Mode Customer ID  \
# Order ID
# CA-2017-152156       1  08/11/2017  11/11/2017    Second Class    CG-12520
# CA-2017-152156       2  08/11/2017  11/11/2017    Second Class    CG-12520
# CA-2017-138688       3  12/06/2017  16/06/2017    Second Class    DV-13045
# US-2016-108966       4  11/10/2016  18/10/2016  Standard Class    SO-20335
# US-2016-108966       5  11/10/2016  18/10/2016  Standard Class    SO-20335
# ...                ...         ...         ...             ...         ...
# CA-2017-125920    9796  21/05/2017  28/05/2017  Standard Class    SH-19975
# CA-2016-128608    9797  12/01/2016  17/01/2016  Standard Class    CS-12490
# CA-2016-128608    9798  12/01/2016  17/01/2016  Standard Class    CS-12490
# CA-2016-128608    9799  12/01/2016  17/01/2016  Standard Class    CS-12490
# CA-2016-128608    9800  12/01/2016  17/01/2016  Standard Class    CS-12490
#
# ...

# %%
df.head()
# Out:
#                 Row ID  Order Date   Ship Date       Ship Mode Customer ID  \
# Order ID
# CA-2017-152156       1  08/11/2017  11/11/2017    Second Class    CG-12520
# CA-2017-152156       2  08/11/2017  11/11/2017    Second Class    CG-12520
# CA-2017-138688       3  12/06/2017  16/06/2017    Second Class    DV-13045
# US-2016-108966       4  11/10/2016  18/10/2016  Standard Class    SO-20335
# US-2016-108966       5  11/10/2016  18/10/2016  Standard Class    SO-20335
#
#                   Customer Name    Segment        Country             City  \
# Order ID
# CA-2017-152156      Claire Gute   Consumer  United States        Henderson
# CA-2017-152156      Claire Gute   Consumer  United States        Henderson
# CA-2017-138688  Darrin Van Huff  Corporate  United States      Los Angeles
# US-2016-108966   Sean O'Donnell   Consumer  United States  Fort Lauderdale
# US-2016-108966   Sean O'Donnell   Consumer  United States  Fort Lauderdale
#
# ...

# %%
df=pd.read_csv('data/dataset.csv', index_col=0)

# %%
df.head()
# Out:
#               Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# Row ID
# 1       CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 2       CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 3       CA-2017-138688  12/06/2017  16/06/2017    Second Class    DV-13045
# 4       US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 5       US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
#
#           Customer Name    Segment        Country             City  \
# Row ID
# 1           Claire Gute   Consumer  United States        Henderson
# 2           Claire Gute   Consumer  United States        Henderson
# 3       Darrin Van Huff  Corporate  United States      Los Angeles
# 4        Sean O'Donnell   Consumer  United States  Fort Lauderdale
# 5        Sean O'Donnell   Consumer  United States  Fort Lauderdale
#
#              State  Postal Code Region       Product ID         Category  \
# Row ID
# ...

# %%
dataset.country
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 dataset.country
#
# NameError: name 'dataset' is not defined

# %%
print(df.country)

# %%
df.country

# %%
df

# %%
df.country

# %%
df['Country'][2]

# %%
df.iloc[3]

# %%
df.iloc[:,4]

# %%
df.iloc[:3,4]

# %%
df.iloc[-6:]

# %%
df

# %%
df.loc[3,'City']

# %%
df.loc[:,'City']

# %%
df.iloc[3,:]

# %%
df.loc[4,['Country','City ']]

# %%
df.loc[:,['City','Country']]

# %%
df.set_index('City')

# %%
df

# %%
df.Category=='Furniture'

# %%
df.loc[df.Category=='Furniture'].shape
# Out:
# (2078, 17)

# %%
df.loc[(df.Category=='Furniture')&(df.Sales>=200) ]
# Out:
#               Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# Row ID
# 1       CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 2       CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 4       US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 11      CA-2015-115812  09/06/2015  14/06/2015  Standard Class    BH-11710
# 25      CA-2016-106320  25/09/2016  30/09/2016  Standard Class    EB-13870
# ...                ...         ...         ...             ...         ...
# 9760    CA-2017-146913  31/10/2017  05/11/2017  Standard Class    SF-20965
# 9770    CA-2017-123533  24/11/2017  30/11/2017  Standard Class    SC-20050
# 9788    CA-2018-144491  27/03/2018  01/04/2018  Standard Class    CJ-12010
# 9789    CA-2018-144491  27/03/2018  01/04/2018  Standard Class    CJ-12010
# 9791    CA-2018-144491  27/03/2018  01/04/2018  Standard Class    CJ-12010
#
# ...

# %%
df

# %%
df.loc[df.City.isin(['Los Angeles','Toledo'])]
# Out:
#               Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# Row ID
# 3       CA-2017-138688  12/06/2017  16/06/2017    Second Class    DV-13045
# 6       CA-2015-115812  09/06/2015  14/06/2015  Standard Class    BH-11710
# 7       CA-2015-115812  09/06/2015  14/06/2015  Standard Class    BH-11710
# 8       CA-2015-115812  09/06/2015  14/06/2015  Standard Class    BH-11710
# 9       CA-2015-115812  09/06/2015  14/06/2015  Standard Class    BH-11710
# ...                ...         ...         ...             ...         ...
# 9765    CA-2015-123855  18/06/2015  23/06/2015  Standard Class    MC-18100
# 9797    CA-2016-128608  12/01/2016  17/01/2016  Standard Class    CS-12490
# 9798    CA-2016-128608  12/01/2016  17/01/2016  Standard Class    CS-12490
# 9799    CA-2016-128608  12/01/2016  17/01/2016  Standard Class    CS-12490
# 9800    CA-2016-128608  12/01/2016  17/01/2016  Standard Class    CS-12490
#
# ...

# %%
df.loc[df.Sales.notnull()]
# Out:
#               Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# Row ID
# 1       CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 2       CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 3       CA-2017-138688  12/06/2017  16/06/2017    Second Class    DV-13045
# 4       US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 5       US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# ...                ...         ...         ...             ...         ...
# 9796    CA-2017-125920  21/05/2017  28/05/2017  Standard Class    SH-19975
# 9797    CA-2016-128608  12/01/2016  17/01/2016  Standard Class    CS-12490
# 9798    CA-2016-128608  12/01/2016  17/01/2016  Standard Class    CS-12490
# 9799    CA-2016-128608  12/01/2016  17/01/2016  Standard Class    CS-12490
# 9800    CA-2016-128608  12/01/2016  17/01/2016  Standard Class    CS-12490
#
# ...

# %%
df.loc[df.City['Ohio'=='ohiooo']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 df.loc[df.City['Ohio'=='ohiooo']]
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\series.py:959, in Series.__getitem__(self, key)
#     954     key = unpack_1tuple(key)
#     956 elif key_is_scalar:
#     957     # Note: GH#50617 in 3.0 we changed int key to always be treated as
#     958     #  a label, matching DataFrame behavior.
# --> 959     return self._get_value(key)
#     961 # Convert generator to list before going through hashable part
#     962 # (We will iterate through the generator there to check for slices)
#     963 if is_iterator(key):
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\series.py:1046, in Series._get_value(self, label, takeable)
#    1043     return self._values[label]
# ...

# %%
df
# Out:
#               Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# Row ID
# 1       CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 2       CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 3       CA-2017-138688  12/06/2017  16/06/2017    Second Class    DV-13045
# 4       US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 5       US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# ...                ...         ...         ...             ...         ...
# 9796    CA-2017-125920  21/05/2017  28/05/2017  Standard Class    SH-19975
# 9797    CA-2016-128608  12/01/2016  17/01/2016  Standard Class    CS-12490
# 9798    CA-2016-128608  12/01/2016  17/01/2016  Standard Class    CS-12490
# 9799    CA-2016-128608  12/01/2016  17/01/2016  Standard Class    CS-12490
# 9800    CA-2016-128608  12/01/2016  17/01/2016  Standard Class    CS-12490
#
# ...

# %%
df['Furniture']='Furn'

# %%
df['Furniture']
# Out:
# Row ID
# 1       Furn
# 2       Furn
# 3       Furn
# 4       Furn
# 5       Furn
#         ...
# 9796    Furn
# 9797    Furn
# 9798    Furn
# 9799    Furn
# 9800    Furn
# Name: Furniture, Length: 9800, dtype: str

# %%
df.len()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 df.len()
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\generic.py:6206, in NDFrame.__getattr__(self, name)
#    6202             and name not in self._accessors
#    6203             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6204         ):
#    6205             return self[name]
# -> 6206         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'len'

# %%
df.len

# %%
len(df)
# Out:
# 9800
