# %%
people={
    'first_name':['ahmad','harry','ali'],
    'last_name':['waleed','harry','harry'],
    'email':['ahmad@mail.com','harry@mail.com','ali@mail.com']
}

# %%
import pandas as pd

# %%
df=pd.DataFrame(people)

# %%
df
# Out:
#   first_name last_name           email
# 0      ahmad    waleed  ahmad@mail.com
# 1      harry     harry  harry@mail.com
# 2        ali     harry    ali@mail.com

# %%
df['last_name']=='harry'
# Out:
# 0    False
# 1     True
# 2     True
# Name: last_name, dtype: bool

# %%
filter=(df['last_name']=='harry') & (df['first_name']=='ali')

# %%
df[filter]
# Out:
#   first_name last_name         email
# 2        ali     harry  ali@mail.com

# %%
df.loc[filter,'email']
# Out:
# 2    ali@mail.com
# Name: email, dtype: str

# %%
df
# Out:
#   first_name last_name           email
# 0      ahmad    waleed  ahmad@mail.com
# 1      harry     harry  harry@mail.com
# 2        ali     harry    ali@mail.com

# %%
df.columns=[x.upper() for x in df.columns]

# %%
df
# Out:
#   FIRST_NAME LAST_NAME           EMAIL
# 0      ahmad    waleed  ahmad@mail.com
# 1      harry     harry  harry@mail.com
# 2        ali     harry    ali@mail.com

# %%
df.columns=df.columns.str.replace('_',' ')

# %%
df
# Out:
#   FIRST NAME LAST NAME           EMAIL
# 0      ahmad    waleed  ahmad@mail.com
# 1      harry     harry  harry@mail.com
# 2        ali     harry    ali@mail.com

# %%
df
# Out:
#   FIRST NAME LAST NAME           EMAIL
# 0      ahmad    waleed  ahmad@mail.com
# 1      harry     harry  harry@mail.com
# 2        ali     harry    ali@mail.com

# %%
df['LAST NAME']
# Out:
# 0    waleed
# 1     harry
# 2     harry
# Name: LAST NAME, dtype: str

# %%
df.columns=df.columns.str.replace('_E_M_A_I_L_','email')

# %%
df
# Out:
#   FIRST NAME LAST NAME           EMAIL
# 0      ahmad    waleed  ahmad@mail.com
# 1      harry     harry  harry@mail.com
# 2        ali     harry    ali@mail.com

# %%
df
# Out:
#   FIRST NAME LAST NAME           EMAIL
# 0      ahmad    waleed  ahmad@mail.com
# 1      harry     harry  harry@mail.com
# 2        ali     harry    ali@mail.com

# %%
df.columns=[x.upper() for x in df.columns]

# %%
df
# Out:
#   FIRST NAME LAST NAME           EMAIL
# 0      ahmad    waleed  ahmad@mail.com
# 1      harry     harry  harry@mail.com
# 2        ali     harry    ali@mail.com

# %%
df.columns=[x.lower() for x in df.columns]

# %%
df
# Out:
#   first name last name           email
# 0      ahmad    waleed  ahmad@mail.com
# 1      harry     harry  harry@mail.com
# 2        ali     harry    ali@mail.com

# %%
df
# Out:
#   first name last name           email
# 0      ahmad    waleed  ahmad@mail.com
# 1      harry     harry  harry@mail.com
# 2        ali     harry    ali@mail.com

# %%
df.columns=['first_name','last_name','email']

# %%
dfd
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 dfd
#
# NameError: name 'dfd' is not defined

# %%
df
# Out:
#   first_name last_name           email
# 0      ahmad    waleed  ahmad@mail.com
# 1      harry     harry  harry@mail.com
# 2        ali     harry    ali@mail.com

# %%
df.columns=[x.upper() for x in df.columns]

# %%
df
# Out:
#   FIRST_NAME LAST_NAME           EMAIL
# 0      ahmad    waleed  ahmad@mail.com
# 1      harry     harry  harry@mail.com
# 2        ali     harry    ali@mail.com

# %%
df.columns=[x.lower() for x in df.columns]

# %%
df
# Out:
#   first_name last_name           email
# 0      ahmad    waleed  ahmad@mail.com
# 1      harry     harry  harry@mail.com
# 2        ali     harry    ali@mail.com

# %%
df.rename(columns={'first_name':'first','last_name':'last'} , inplace=True)

# %%
df
# Out:
#    first    last           email
# 0  ahmad  waleed  ahmad@mail.com
# 1  harry   harry  harry@mail.com
# 2    ali   harry    ali@mail.com

# %%
df
# Out:
#    first    last           email
# 0  ahmad  waleed  ahmad@mail.com
# 1  harry   harry  harry@mail.com
# 2    ali   harry    ali@mail.com

# %%
def update_email(email):
 return email.upper()

# %%
df['email'].apply(update_email)
# Out:
# 0    AHMAD@MAIL.COM
# 1    HARRY@MAIL.COM
# 2      ALI@MAIL.COM
# Name: email, dtype: str

# %%
df['email']=df['email'].apply(update_email)

# %%
df
# Out:
#    first    last           email
# 0  ahmad  waleed  AHMAD@MAIL.COM
# 1  harry   harry  HARRY@MAIL.COM
# 2    ali   harry    ALI@MAIL.COM

# %%
df['email']=df['email'].apply(lambda x : x.lower())

# %%
df
# Out:
#    first    last           email
# 0  ahmad  waleed  ahmad@mail.com
# 1  harry   harry  harry@mail.com
# 2    ali   harry    ali@mail.com

# %%
df.applymap(len)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 df.applymap(len)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\generic.py:6206, in NDFrame.__getattr__(self, name)
#    6202             and name not in self._accessors
#    6203             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6204         ):
#    6205             return self[name]
# -> 6206         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'applymap'

# %%
df.apply(lambda x: x.min())
# Out:
# first             ahmad
# last              harry
# email    ahmad@mail.com
# dtype: str

# %%
df.map(len)
# Out:
#    first  last  email
# 0      5     6     14
# 1      5     5     14
# 2      3     5     12

# %%
df.apply(len)
# Out:
# first    3
# last     3
# email    3
# dtype: int64

# %%
df['last'].apply(len)
# Out:
# 0    6
# 1    5
# 2    5
# Name: last, dtype: int64

# %%
df.map(len)
# Out:
#    first  last  email
# 0      5     6     14
# 1      5     5     14
# 2      3     5     12

# %%
df.map(min)
# Out:
#   first last email
# 0     a    a     .
# 1     a    a     .
# 2     a    a     .

# %%
df['last'].apply(lower())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 df['last'].apply(lower())
#
# NameError: name 'lower' is not defined

# %%
df['last']=df['last'].apply(lambda x: x.lower())

# %%
df
# Out:
#    first    last           email
# 0  ahmad  waleed  ahmad@mail.com
# 1  harry   harry  harry@mail.com
# 2    ali   harry    ali@mail.com

# %%
df.map(str.lower)
# Out:
#    first    last           email
# 0  ahmad  waleed  ahmad@mail.com
# 1  harry   harry  harry@mail.com
# 2    ali   harry    ali@mail.com

# %%
df['last']=df['last'].apply(str.lower)

# %%
df
# Out:
#    first    last           email
# 0  ahmad  waleed  ahmad@mail.com
# 1  harry   harry  harry@mail.com
# 2    ali   harry    ali@mail.com

# %%
df.map(str.upper)
# Out:
#    first    last           email
# 0  AHMAD  WALEED  AHMAD@MAIL.COM
# 1  HARRY   HARRY  HARRY@MAIL.COM
# 2    ALI   HARRY    ALI@MAIL.COM

# %%
df['first'].replace({'HARRY':'harry'})
# Out:
# 0    ahmad
# 1    harry
# 2      ali
# Name: first, dtype: str

# %%
df['first']=df['first'].replace({'HARRY':'harry'})

# %%
df
# Out:
#    first    last           email
# 0  ahmad  waleed  ahmad@mail.com
# 1  harry   harry  harry@mail.com
# 2    ali   harry    ali@mail.com

# %%
df['full name']=df['first']+' ' + df['last']

# %%
df
# Out:
#    first    last           email     full name
# 0  ahmad  waleed  ahmad@mail.com  ahmad waleed
# 1  harry   harry  harry@mail.com   harry harry
# 2    ali   harry    ali@mail.com     ali harry

# %%
df.drop(columns=['first','last'])
# Out:
#             email     full name
# 0  ahmad@mail.com  ahmad waleed
# 1  harry@mail.com   harry harry
# 2    ali@mail.com     ali harry

# %%
df['full name'].str.split(' ', expand=True)
# Out:
#        0       1
# 0  ahmad  waleed
# 1  harry   harry
# 2    ali   harry

# %%
df[['first','last']]=df['full name'].str.split(' ', expand=True)

# %%
df
# Out:
#    first    last           email     full name
# 0  ahmad  waleed  ahmad@mail.com  ahmad waleed
# 1  harry   harry  harry@mail.com   harry harry
# 2    ali   harry    ali@mail.com     ali harry

# %%
people:{
    'first':['tony','steve'],
    'last':['stark','rogers'],
    'email':['tony@mail.com','steve@mail.com']

}
df2=pd.DataFrame(people)

# %%
df2
# Out:
#   first_name last_name           email
# 0      ahmad    waleed  ahmad@mail.com
# 1      harry     harry  harry@mail.com
# 2        ali     harry    ali@mail.com

# %%
df
# Out:
#    first    last           email     full name
# 0  ahmad  waleed  ahmad@mail.com  ahmad waleed
# 1  harry   harry  harry@mail.com   harry harry
# 2    ali   harry    ali@mail.com     ali harry

# %%
df.append({'first':'tonyy'}, ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[84], line 1
# ----> 1 df.append({'first':'tonyy'}, ignore_index=True)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\generic.py:6206, in NDFrame.__getattr__(self, name)
#    6202             and name not in self._accessors
#    6203             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6204         ):
#    6205             return self[name]
# -> 6206         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %%
df = pd.concat(
    [df, pd.DataFrame([{'first': 'tonyy'}])],
    ignore_index=True
)

# %%
df
# Out:
#    first    last           email     full name
# 0  ahmad  waleed  ahmad@mail.com  ahmad waleed
# 1  harry   harry  harry@mail.com   harry harry
# 2    ali   harry    ali@mail.com     ali harry
# 3  tonyy     NaN             NaN           NaN
